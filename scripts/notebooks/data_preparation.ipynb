# %%
import sys
import os
sys.path.append("/home/milugu/ml_env/src/option_analyzer")
from data_utils.data_utils import DataManager
import logging

logging.basicConfig(format='%(levelname)s - %(name)s -: %(asctime)s %(message)s',
                    level=logging.INFO)

# %%
dm_spy = DataManager(api = 'alpha_vantage')

data = dm_spy.get_historical_data(symbol = 'SPY', interval = 'daily', start='01/05/2010')
data.head()
# Out:
# WARNING - Data Manager -: 2020-03-22 15:26:40,166 No attributes specified. Returning all columns!
# WARNING - Data Manager -: 2020-03-22 15:26:40,170 No end date specified. Returning till the last row!
# /home/milugu/ml_env/src/option_analyzer/data_utils/data_utils.py:121: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   data = raw_data.loc[row_range].copy()
#             3. low  1. open  2. high  4. close    6. volume  \
# 2010-01-05  112.85   113.26   113.68    113.63  111519230.0
# 2010-01-06  113.43   113.52   113.99    113.71  116017127.0
# 2010-01-07  113.18   113.50   114.33    114.19  130502017.0
# 2010-01-08  113.66   113.89   114.62    114.57  126357911.0
# 2010-01-09     NaN      NaN      NaN       NaN          NaN
#
# ...

# %%
data.shape
# Out:
# (3728, 40)
